# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
import requests

r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '24234739667',
#   'type': 'PushEvent',
#   'actor': {'id': 47361858,
#    'login': 'derrk',
#    'display_login': 'derrk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/derrk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47361858?'},
#   'repo': {'id': 536472567,
#    'name': 'derrk/TreasureFinder',
#    'url': 'https://api.github.com/repos/derrk/TreasureFinder'},
#   'payload': {'push_id': 11142760118,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7c594b6f166ca351e12204cb4023dfc7209faa1b',
#    'before': 'e4c41a4039b1b3ae3ffafee9f197252dd1085d29',
#    'commits': [{'sha': '7c594b6f166ca351e12204cb4023dfc7209faa1b',
#      'author': {'email': 'derrik.pollock@gmail.com', 'name': 'derrk'},
#      'message': 'working besides print map',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/derrk/TreasureFinder/commits/7c594b6f166ca351e12204cb4023dfc7209faa1b'}]},
#   'public': True,
# ...
